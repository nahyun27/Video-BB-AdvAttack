# %%
!
!
# !pip install langchain
# Out:
# WARNING: Ignoring invalid distribution -11 (/etc/anaconda3/lib/python3.9/site-packages)
# WARNING: Ignoring invalid distribution -3transfer (/etc/anaconda3/lib/python3.9/site-packages)
# WARNING: Ignoring invalid distribution -capy (/etc/anaconda3/lib/python3.9/site-packages)
# WARNING: Ignoring invalid distribution -cipy (/etc/anaconda3/lib/python3.9/site-packages)
# WARNING: Ignoring invalid distribution -ebsocket-client (/etc/anaconda3/lib/python3.9/site-packages)
# WARNING: Ignoring invalid distribution -ensorboard-data-server (/etc/anaconda3/lib/python3.9/site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-estimator (/etc/anaconda3/lib/python3.9/site-packages)
# WARNING: Ignoring invalid distribution -eras (/etc/anaconda3/lib/python3.9/site-packages)
# WARNING: Ignoring invalid distribution -illow (/etc/anaconda3/lib/python3.9/site-packages)
# WARNING: Ignoring invalid distribution -inja (/etc/anaconda3/lib/python3.9/site-packages)
# WARNING: Ignoring invalid distribution -ip (/etc/anaconda3/lib/python3.9/site-packages)
# WARNING: Ignoring invalid distribution -latbuffers (/etc/anaconda3/lib/python3.9/site-packages)
# WARNING: Ignoring invalid distribution -mcv (/etc/anaconda3/lib/python3.9/site-packages)
# WARNING: Ignoring invalid distribution -mengine (/etc/anaconda3/lib/python3.9/site-packages)
# WARNING: Ignoring invalid distribution -ntlr4-python3-runtime (/etc/anaconda3/lib/python3.9/site-packages)
# WARNING: Ignoring invalid distribution -orch (/etc/anaconda3/lib/python3.9/site-packages)
# WARNING: Ignoring invalid distribution -orchvision (/etc/anaconda3/lib/python3.9/site-packages)
# WARNING: Ignoring invalid distribution -oto3 (/etc/anaconda3/lib/python3.9/site-packages)
# WARNING: Ignoring invalid distribution -otocore (/etc/anaconda3/lib/python3.9/site-packages)
# WARNING: Ignoring invalid distribution -roto-plus (/etc/anaconda3/lib/python3.9/site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (/etc/anaconda3/lib/python3.9/site-packages)
# WARNING: Ignoring invalid distribution -ttpcore (/etc/anaconda3/lib/python3.9/site-packages)
# WARNING: Ignoring invalid distribution -ttpx (/etc/anaconda3/lib/python3.9/site-packages)
# WARNING: Ignoring invalid distribution -ttrs (/etc/anaconda3/lib/python3.9/site-packages)
# WARNING: Ignoring invalid distribution -umpy (/etc/anaconda3/lib/python3.9/site-packages)
# WARNING: Ignoring invalid distribution -yping-extensions (/etc/anaconda3/lib/python3.9/site-packages)
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# Collecting langchain
#   Downloading langchain-0.1.17-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: PyYAML>=5.3 in /etc/anaconda3/lib/python3.9/site-packages (from langchain) (5.4.1)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /etc/anaconda3/lib/python3.9/site-packages (from langchain) (1.4.46)
# Collecting aiohttp<4.0.0,>=3.8.3 (from langchain)
#   Downloading aiohttp-3.9.5-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (7.5 kB)
# Requirement already satisfied: async-timeout<5.0.0,>=4.0.0 in /etc/anaconda3/lib/python3.9/site-packages (from langchain) (4.0.2)
# Collecting dataclasses-json<0.7,>=0.5.7 (from langchain)
#   Downloading dataclasses_json-0.6.5-py3-none-any.whl.metadata (25 kB)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /etc/anaconda3/lib/python3.9/site-packages (from langchain) (1.33)
# Collecting langchain-community<0.1,>=0.0.36 (from langchain)
#   Downloading langchain_community-0.0.36-py3-none-any.whl.metadata (8.7 kB)
# Collecting langchain-core<0.2.0,>=0.1.48 (from langchain)
#   Downloading langchain_core-0.1.48-py3-none-any.whl.metadata (5.9 kB)
# Collecting langchain-text-splitters<0.1,>=0.0.1 (from langchain)
#   Downloading langchain_text_splitters-0.0.1-py3-none-any.whl.metadata (2.0 kB)
# Collecting langsmith<0.2.0,>=0.1.17 (from langchain)
#   Downloading langsmith-0.1.52-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: numpy<2,>=1 in /etc/anaconda3/lib/python3.9/site-packages (from langchain) (1.25.2)
# Requirement already satisfied: pydantic<3,>=1 in /etc/anaconda3/lib/python3.9/site-packages (from langchain) (1.10.6)
# Requirement already satisfied: requests<3,>=2 in /etc/anaconda3/lib/python3.9/site-packages (from langchain) (2.31.0)
# Requirement already satisfied: tenacity<9.0.0,>=8.1.0 in /etc/anaconda3/lib/python3.9/site-packages (from langchain) (8.2.2)
# Requirement already satisfied: aiosignal>=1.1.2 in /etc/anaconda3/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.2.0)
# Requirement already satisfied: attrs>=17.3.0 in /etc/anaconda3/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /etc/anaconda3/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.3.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /etc/anaconda3/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (6.0.2)
# Requirement already satisfied: yarl<2.0,>=1.0 in /etc/anaconda3/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.7.2)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /etc/anaconda3/lib/python3.9/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain) (3.19.0)
# Collecting typing-inspect<1,>=0.4.0 (from dataclasses-json<0.7,>=0.5.7->langchain)
#   Downloading typing_inspect-0.9.0-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: jsonpointer>=1.9 in /etc/anaconda3/lib/python3.9/site-packages (from jsonpatch<2.0,>=1.33->langchain) (2.4)
# Collecting packaging<24.0,>=23.2 (from langchain-core<0.2.0,>=0.1.48->langchain)
#   Downloading packaging-23.2-py3-none-any.whl.metadata (3.2 kB)
# Collecting orjson<4.0.0,>=3.9.14 (from langsmith<0.2.0,>=0.1.17->langchain)
#   Downloading orjson-3.10.2-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (49 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.7/49.7 kB 3.3 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions>=4.2.0 in /etc/anaconda3/lib/python3.9/site-packages (from pydantic<3,>=1->langchain) (4.8.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /etc/anaconda3/lib/python3.9/site-packages (from requests<3,>=2->langchain) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /etc/anaconda3/lib/python3.9/site-packages (from requests<3,>=2->langchain) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /etc/anaconda3/lib/python3.9/site-packages (from requests<3,>=2->langchain) (1.26.14)
# Requirement already satisfied: certifi>=2017.4.17 in /etc/anaconda3/lib/python3.9/site-packages (from requests<3,>=2->langchain) (2022.12.7)
# Requirement already satisfied: greenlet!=0.4.17 in /etc/anaconda3/lib/python3.9/site-packages (from SQLAlchemy<3,>=1.4->langchain) (2.0.1)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /etc/anaconda3/lib/python3.9/site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain) (0.4.3)
# Downloading langchain-0.1.17-py3-none-any.whl (867 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 867.6/867.6 kB 5.3 MB/s eta 0:00:00a 0:00:01
# Downloading aiohttp-3.9.5-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 5.7 MB/s eta 0:00:00a 0:00:01
# Downloading dataclasses_json-0.6.5-py3-none-any.whl (28 kB)
# Downloading langchain_community-0.0.36-py3-none-any.whl (2.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 4.4 MB/s eta 0:00:00a 0:00:01
# Downloading langchain_core-0.1.48-py3-none-any.whl (302 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 302.9/302.9 kB 4.9 MB/s eta 0:00:00a 0:00:01
# Downloading langchain_text_splitters-0.0.1-py3-none-any.whl (21 kB)
# Downloading langsmith-0.1.52-py3-none-any.whl (116 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.4/116.4 kB 5.4 MB/s eta 0:00:00
# Downloading orjson-3.10.2-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (142 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 142.5/142.5 kB 5.7 MB/s eta 0:00:00
# Downloading packaging-23.2-py3-none-any.whl (53 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.0/53.0 kB 6.7 MB/s eta 0:00:00
# Downloading typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# WARNING: Ignoring invalid distribution -11 (/etc/anaconda3/lib/python3.9/site-packages)
# WARNING: Ignoring invalid distribution -3transfer (/etc/anaconda3/lib/python3.9/site-packages)
# WARNING: Ignoring invalid distribution -capy (/etc/anaconda3/lib/python3.9/site-packages)
# WARNING: Ignoring invalid distribution -cipy (/etc/anaconda3/lib/python3.9/site-packages)
# WARNING: Ignoring invalid distribution -ebsocket-client (/etc/anaconda3/lib/python3.9/site-packages)
# WARNING: Ignoring invalid distribution -ensorboard-data-server (/etc/anaconda3/lib/python3.9/site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-estimator (/etc/anaconda3/lib/python3.9/site-packages)
# WARNING: Ignoring invalid distribution -eras (/etc/anaconda3/lib/python3.9/site-packages)
# WARNING: Ignoring invalid distribution -illow (/etc/anaconda3/lib/python3.9/site-packages)
# WARNING: Ignoring invalid distribution -inja (/etc/anaconda3/lib/python3.9/site-packages)
# WARNING: Ignoring invalid distribution -ip (/etc/anaconda3/lib/python3.9/site-packages)
# WARNING: Ignoring invalid distribution -latbuffers (/etc/anaconda3/lib/python3.9/site-packages)
# WARNING: Ignoring invalid distribution -mcv (/etc/anaconda3/lib/python3.9/site-packages)
# WARNING: Ignoring invalid distribution -mengine (/etc/anaconda3/lib/python3.9/site-packages)
# WARNING: Ignoring invalid distribution -ntlr4-python3-runtime (/etc/anaconda3/lib/python3.9/site-packages)
# WARNING: Ignoring invalid distribution -orch (/etc/anaconda3/lib/python3.9/site-packages)
# WARNING: Ignoring invalid distribution -orchvision (/etc/anaconda3/lib/python3.9/site-packages)
# WARNING: Ignoring invalid distribution -oto3 (/etc/anaconda3/lib/python3.9/site-packages)
# WARNING: Ignoring invalid distribution -otocore (/etc/anaconda3/lib/python3.9/site-packages)
# WARNING: Ignoring invalid distribution -roto-plus (/etc/anaconda3/lib/python3.9/site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (/etc/anaconda3/lib/python3.9/site-packages)
# WARNING: Ignoring invalid distribution -ttpcore (/etc/anaconda3/lib/python3.9/site-packages)
# WARNING: Ignoring invalid distribution -ttpx (/etc/anaconda3/lib/python3.9/site-packages)
# WARNING: Ignoring invalid distribution -ttrs (/etc/anaconda3/lib/python3.9/site-packages)
# WARNING: Ignoring invalid distribution -umpy (/etc/anaconda3/lib/python3.9/site-packages)
# WARNING: Ignoring invalid distribution -yping-extensions (/etc/anaconda3/lib/python3.9/site-packages)
# Installing collected packages: typing-inspect, packaging, orjson, langsmith, aiohttp, langchain-core, dataclasses-json, langchain-text-splitters, langchain-community, langchain
#   Attempting uninstall: packaging
#     Found existing installation: packaging 22.0
#     Uninstalling packaging-22.0:
#       Successfully uninstalled packaging-22.0
#   WARNING: Failed to remove contents in a temporary directory '/etc/anaconda3/lib/python3.9/site-packages/~ackaging-22.0.dist-info'.
#   You can safely remove it manually.
#   Attempting uninstall: orjson
#     Found existing installation: orjson 3.8.5
#     Uninstalling orjson-3.8.5:
#       Successfully uninstalled orjson-3.8.5
#   WARNING: Failed to remove contents in a temporary directory '/etc/anaconda3/lib/python3.9/site-packages/~rjson-3.8.5.dist-info'.
#   You can safely remove it manually.
#   WARNING: Failed to remove contents in a temporary directory '/etc/anaconda3/lib/python3.9/site-packages/~rjson'.
#   You can safely remove it manually.
#   Attempting uninstall: aiohttp
#     Found existing installation: aiohttp 3.8.1
#     Uninstalling aiohttp-3.8.1:
#       Successfully uninstalled aiohttp-3.8.1
#   WARNING: Failed to remove contents in a temporary directory '/etc/anaconda3/lib/python3.9/site-packages/~iohttp'.
#   You can safely remove it manually.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# mmaction 0.5.0 requires Pillow<=6.2.2, but you have pillow 10.2.0 which is incompatible.
# pytorch-lightning 1.9.0 requires torch>=1.10.0, but you have torch 1.7.1+cu110 which is incompatible.
# tensorflow-gpu 2.11.0 requires protobuf<3.20,>=3.9.2, but you have protobuf 3.20.0 which is incompatible.
# Successfully installed aiohttp-3.8.3 dataclasses-json-0.6.5 langchain-0.1.17 langchain-community-0.0.36 langchain-core-0.1.48 langchain-text-splitters-0.0.1 langsmith-0.1.52 orjson-3.10.2 packaging-23.2 typing-inspect-0.9.0

# %%
from langchain.chat_models import ChatOpenAI
from langchain.document_loaders import UnstructuredFileLoader
from langchain.text_splitter import CharacterTextSplitter
from langchain.embeddings import OpenAIEmbeddings, CacheBackedEmbeddings
from langchain.vectorstores import Chroma
from langchain.storage import LocalFileStore
from langchain.chains import RetrievalQA

model = ChatOpenAI()
data_loader = UnstructuredFileLoader ("files/wiki.txt")
cache_dir = LocalFileStore("./.cache/")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-4-6e8001b0db83> in <module>()
# ----> 1 from langchain.chat_models import ChatOpenAI
#       2 from langchain.document_loaders import UnstructuredFileLoader
#       3 from langchain.text_splitter import CharacterTextSplitter
#       4 from langchain.embeddings import OpenAIEmbeddings, CacheBackedEmbeddings
#       5 from langchain.vectorstores import Chroma
#
# ModuleNotFoundError: No module named 'langchain'
